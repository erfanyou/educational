# %%
import pandas as pd


df= pd.read_excel("./Data/CarsENCols.xlsx" , index_col = 0 )

# %%
df.head(39)
# Out:
#                Date   Milage                 VIN        Made   Model  \
# index
# 0        1400-1-تیر  24393.0  NA0000000000000200       سایپا   پراید
# 1        1400-2-تیر  18177.0  NA0000000000000201       سایپا   پراید
# 2        1400-3-تیر  20600.0  NA0000000000000202       سایپا   پراید
# 3        1400-4-تیر  26210.0  NA0000000000000203       سایپا   پراید
# 4        1400-5-تیر  24213.0  NA0000000000000204       سایپا   پراید
# 5        1400-6-تیر  24628.0  NA0000000000000205       سایپا   پراید
# 6        1400-7-تیر  26879.0  NA0000000000000206       سایپا   پراید
# 7        1400-8-تیر  26333.0  NA0000000000000207       سایپا   پراید
# 8        1400-9-تیر  32992.0  NA0000000000000208       سایپا   پراید
# 9       1400-10-تیر  36638.0  NA0000000000000209       سایپا   پراید
# 10      1400-11-تیر   8945.0  NA0000000000000210       سایپا   پراید
# 11      1400-12-تیر  10985.0  NA0000000000000211       سایپا   پراید
# ...

# %%
# df[df['VIN'] != 'NA0000000000000203']

# %%
block_list = ['NA0000000000000203' , 'NA0000000000000233' ]

df[~df['VIN'].isin(block_list)]
# Out:
#                 Date   Milage                 VIN        Made   Model  \
# index
# 0         1400-1-تیر  24393.0  NA0000000000000200       سایپا   پراید
# 1         1400-2-تیر  18177.0  NA0000000000000201       سایپا   پراید
# 2         1400-3-تیر  20600.0  NA0000000000000202       سایپا   پراید
# 4         1400-5-تیر  24213.0  NA0000000000000204       سایپا   پراید
# 5         1400-6-تیر  24628.0  NA0000000000000205       سایپا   پراید
# ...              ...      ...                 ...         ...     ...
# 192     1400-7-مرداد  20468.0  NA0000000000000392  ایرانخودرو  پژو206
# 193     1400-8-مرداد  20747.0  NA0000000000000393  ایرانخودرو  پژو206
# 194     1400-9-مرداد  20397.0  NA0000000000000394  ایرانخودرو  پژو206
# 195    1400-10-مرداد  24358.0  NA0000000000000395  ایرانخودرو  پژو206
# 196    1400-11-مرداد  27363.0  NA0000000000000396  ایرانخودرو  پژو206
#
#             Type       Price       Order     Explain
# index
# 0      Hatchback  17049382.0  17000000.0      بی رنگ
# ...

# %%
df[df["Made"].notnull()]
# Out:
#                 Date   Milage                 VIN        Made   Model  \
# index
# 0         1400-1-تیر  24393.0  NA0000000000000200       سایپا   پراید
# 1         1400-2-تیر  18177.0  NA0000000000000201       سایپا   پراید
# 2         1400-3-تیر  20600.0  NA0000000000000202       سایپا   پراید
# 3         1400-4-تیر  26210.0  NA0000000000000203       سایپا   پراید
# 4         1400-5-تیر  24213.0  NA0000000000000204       سایپا   پراید
# ...              ...      ...                 ...         ...     ...
# 192     1400-7-مرداد  20468.0  NA0000000000000392  ایرانخودرو  پژو206
# 193     1400-8-مرداد  20747.0  NA0000000000000393  ایرانخودرو  پژو206
# 194     1400-9-مرداد  20397.0  NA0000000000000394  ایرانخودرو  پژو206
# 195    1400-10-مرداد  24358.0  NA0000000000000395  ایرانخودرو  پژو206
# 196    1400-11-مرداد  27363.0  NA0000000000000396  ایرانخودرو  پژو206
#
#             Type       Price       Order     Explain
# index
# 0      Hatchback  17049382.0  17000000.0      بی رنگ
# ...

# %%
df[(df["Milage"] >35000) ^ (df['Type'] == 'Hatchback' )].head(2)
# Out:
#              Date   Milage                 VIN   Made  Model       Type  \
# index
# 0      1400-1-تیر  24393.0  NA0000000000000200  سایپا  پراید  Hatchback
# 1      1400-2-تیر  18177.0  NA0000000000000201  سایپا  پراید  Hatchback
#
#             Price       Order Explain
# index
# 0      17049382.0  17000000.0  بی رنگ
# 1      20059011.0  17000000.0   بیرنگ

# %%
df.isnull().any()
# Out:
# Date       True
# Milage     True
# VIN        True
# Made       True
# Model      True
# Type       True
# Price      True
# Order      True
# Explain    True
# dtype: bool
