# %%
import pandas as pd


df = pd.read_excel("./Data/CarsENCols.xlsx" , index_col = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 197 entries, 0 to 196
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     193 non-null    object
#  1   Milage   196 non-null    float64
#  2   VIN      196 non-null    object
#  3   Made     194 non-null    object
#  4   Model    195 non-null    object
#  5   Type     196 non-null    object
#  6   Price    194 non-null    float64
#  7   Order    195 non-null    float64
#  8   Explain  193 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 15.4+ KB

# %%
df.dropna(subset = ["Date" , "Milage" , "VIN"] , axis= 0 , inplace = True)

# %%
df.shape
# Out:
# (191, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 0 to 196
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     191 non-null    object
#  1   Milage   191 non-null    float64
#  2   VIN      191 non-null    object
#  3   Made     190 non-null    object
#  4   Model    191 non-null    object
#  5   Type     190 non-null    object
#  6   Price    189 non-null    float64
#  7   Order    189 non-null    float64
#  8   Explain  188 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 14.9+ KB

# %%
df[df['Made'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Milage, VIN, Made, Model, Type, Price, Order, Explain]
# Index: []

# %%
df['Made'].unique()
# Out:
# array(['سایپا', 'ایرانخودرو', nan], dtype=object)

# %%
df.at[136 , 'Made'] = 'سایپا'

# %%
df['Made'].unique()
# Out:
# array(['سایپا', 'ایرانخودرو'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 0 to 196
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     191 non-null    object
#  1   Milage   191 non-null    float64
#  2   VIN      191 non-null    object
#  3   Made     191 non-null    object
#  4   Model    191 non-null    object
#  5   Type     190 non-null    object
#  6   Price    189 non-null    float64
#  7   Order    189 non-null    float64
#  8   Explain  188 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 19.0+ KB

# %%
df[df['Type'].isnull()]
# Out:
#                  Date   Milage                 VIN        Made   Model Type  \
# index
# 164    1400-10-شهریور  20772.0  NA0000000000000364  ایرانخودرو  پژو206  NaN
#
#             Price       Order Explain
# index
# 164    25266099.0  22000000.0     NaN

# %%
df['Type'].unique()
# Out:
# array(['Hatchback', 'Sedan', nan], dtype=object)

# %%
df.pivot_table(columns= ['Model', 'Type'] , values= 'Order')
# Out:
# Model       پراید                    پژو206
# Type    Hatchback       Sedan     Hatchback       Sedan
# Order  17000000.0  15000000.0  2.111864e+07  21000000.0

# %%
df[df['Model'] == 'پژو206']['Order'].unique()
# Out:
# array([20000000., 22000000., 21000000.])

# %%
df.at[164, "Type"] = 'Hatchback'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 191 entries, 0 to 196
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     191 non-null    object
#  1   Milage   191 non-null    float64
#  2   VIN      191 non-null    object
#  3   Made     191 non-null    object
#  4   Model    191 non-null    object
#  5   Type     191 non-null    object
#  6   Price    189 non-null    float64
#  7   Order    189 non-null    float64
#  8   Explain  188 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 19.0+ KB

# %%
df.fillna(method='ffill').tail(50)
# Out:
# C:\Users\Esfandiari\AppData\Local\Temp\ipykernel_3028\1665900036.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill').tail(50)
#                  Date   Milage                 VIN        Made   Model  \
# index
# 143     1400-20-مرداد  12063.0  NA0000000000000343       سایپا   پراید
# 144     1400-21-مرداد  11523.0  NA0000000000000344       سایپا   پراید
# 145     1400-22-مرداد  14689.0  NA0000000000000345       سایپا   پراید
# 146     1400-23-مرداد  17956.0  NA0000000000000346       سایپا   پراید
# 147     1400-24-مرداد  20449.0  NA0000000000000347       سایپا   پراید
# 148     1400-25-مرداد  23776.0  NA0000000000000348       سایپا   پراید
# 149     1400-26-مرداد  24675.0  NA0000000000000349       سایپا   پراید
# 150     1400-27-مرداد  25088.0  NA0000000000000350       سایپا   پراید
# 151     1400-28-مرداد  28728.0  NA0000000000000351       سایپا   پراید
# ...

# %%
df.dropna().to_excel("./Data/CleanData.xlsx")

# %%
df.dropna(inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184 entries, 0 to 196
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     184 non-null    object
#  1   Milage   184 non-null    float64
#  2   VIN      184 non-null    object
#  3   Made     184 non-null    object
#  4   Model    184 non-null    object
#  5   Type     184 non-null    object
#  6   Price    184 non-null    float64
#  7   Order    184 non-null    float64
#  8   Explain  184 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 14.4+ KB

# %%
df_clean = pd.read_excel("./Data/CleanData.xlsx")

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    184 non-null    int64
#  1   Date     184 non-null    object
#  2   Milage   184 non-null    int64
#  3   VIN      184 non-null    object
#  4   Made     184 non-null    object
#  5   Model    184 non-null    object
#  6   Type     184 non-null    object
#  7   Price    184 non-null    int64
#  8   Order    184 non-null    int64
#  9   Explain  184 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 14.5+ KB
